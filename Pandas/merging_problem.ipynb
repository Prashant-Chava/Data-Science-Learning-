# %%
# pandas

# %%
import pandas as pd

# %%
df1 = pd.read_csv("matches.csv")

# %%
df2 = pd.read_csv('deliveries.csv')

# %%
df1.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
df2.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
merge = pd.merge(df1,df2,left_on='id', right_on='match_id', how= 'inner')

# %%
merge
# Out:
#              id   season       city        date match_type player_of_match  \
# 0        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 1        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 2        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 3        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 4        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# ...         ...      ...        ...         ...        ...             ...
# 260915  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260916  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260917  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260918  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260919  1426312     2024    Chennai  2024-05-26      Final        MA Starc
#
# ...

# %%
df1.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
winner = merge[['id','toss_winner','winner']]

# %%
winner
# Out:
#              id                  toss_winner                 winner
# 0        335982  Royal Challengers Bangalore  Kolkata Knight Riders
# 1        335982  Royal Challengers Bangalore  Kolkata Knight Riders
# 2        335982  Royal Challengers Bangalore  Kolkata Knight Riders
# 3        335982  Royal Challengers Bangalore  Kolkata Knight Riders
# 4        335982  Royal Challengers Bangalore  Kolkata Knight Riders
# ...         ...                          ...                    ...
# 260915  1426312          Sunrisers Hyderabad  Kolkata Knight Riders
# 260916  1426312          Sunrisers Hyderabad  Kolkata Knight Riders
# 260917  1426312          Sunrisers Hyderabad  Kolkata Knight Riders
# 260918  1426312          Sunrisers Hyderabad  Kolkata Knight Riders
# 260919  1426312          Sunrisers Hyderabad  Kolkata Knight Riders
#
# [260920 rows x 3 columns]

# %%
# res = pd.merge(winner , df2 , left_on = 'id' , right_on = 'match_id' , how = 'inner')

# %%
# res

# %%
# res = pd.merge(winner ,df2,left_on='id', right_on='match_id', how= 'inner')

# %%
# extract all wickt taken in matches play in eden garden

# %%
merge.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2', 'match_id', 'inning', 'batting_team',
#        'bowling_team', 'over', 'ball', 'batter', 'bowler', 'non_striker',
#        'batsman_runs', 'extra_runs', 'total_runs', 'extras_type', 'is_wicket',
#        'player_dismissed', 'dismissal_kind', 'fielder', 'is_final', 'matchup',
#        'merge_type', 'powerplay_ball', 'inning_type'],
#       dtype='object')

# %%
res = merge['']

# %%
wickets = merge[['id','venue','is_wicket']]

# %%
res = wickets[wickets['venue'] == 'Eden Garden']

# %%
# get all the deliveris of super overs

# %%
super = df1[['id', 'super_over']]

# %%
res = pd.merge(super , df2 , left_on='id', right_on='match_id', how = 'inner')

# %%
super_res = res[res['super_over'] == 'yes']

# %%
super_res
# Out:
# Empty DataFrame
# Columns: [id, super_over, match_id, inning, batting_team, bowling_team, over, ball, batter, bowler, non_striker, batsman_runs, extra_runs, total_runs, extras_type, is_wicket, player_dismissed, dismissal_kind, fielder]
# Index: []

# %%
field = df1[['id','toss_decision']]

# %%
res = pd.merge(field , df2 , left_on ='id' , right_on='match_id' , how = 'inner')

# %%
res[res['toss_decision'] == 'field']
# Out:
#              id toss_decision  match_id  inning           batting_team  \
# 0        335982         field    335982       1  Kolkata Knight Riders
# 1        335982         field    335982       1  Kolkata Knight Riders
# 2        335982         field    335982       1  Kolkata Knight Riders
# 3        335982         field    335982       1  Kolkata Knight Riders
# 4        335982         field    335982       1  Kolkata Knight Riders
# ...         ...           ...       ...     ...                    ...
# 260731  1426311         field   1426311       2       Rajasthan Royals
# 260732  1426311         field   1426311       2       Rajasthan Royals
# 260733  1426311         field   1426311       2       Rajasthan Royals
# 260734  1426311         field   1426311       2       Rajasthan Royals
# 260735  1426311         field   1426311       2       Rajasthan Royals
#
#                        bowling_team  over  ball       batter       bowler  \
# ...

# %%
df1.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
df2['ball']
# Out:
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5
#          ..
# 260915    5
# 260916    6
# 260917    1
# 260918    2
# 260919    3
# Name: ball, Length: 260920, dtype: int64

# %%
data1 = df1[['id' , 'result']]

# %%
res2 = pd.merge(data1 , df2 , left_on ='id' , right_on='match_id' , how = 'inner')

# %%
res2[res2['dismissal_kind'] == 'bowled']
# Out:
#              id   result  match_id  inning                 batting_team  \
# 131      335982     runs    335982       2  Royal Challengers Bangalore
# 138      335982     runs    335982       2  Royal Challengers Bangalore
# 210      335982     runs    335982       2  Royal Challengers Bangalore
# 264      335983     runs    335983       1          Chennai Super Kings
# 321      335983     runs    335983       1          Chennai Super Kings
# ...         ...      ...       ...     ...                          ...
# 260569  1426311     runs   1426311       1          Sunrisers Hyderabad
# 260599  1426311     runs   1426311       1          Sunrisers Hyderabad
# 260696  1426311     runs   1426311       2             Rajasthan Royals
# 260740  1426312  wickets   1426312       1          Sunrisers Hyderabad
# 260826  1426312  wickets   1426312       1          Sunrisers Hyderabad
#
#                  bowling_team  over  ball           batter           bowler  \
# ...

# %%
mi = df1[(df1['team1'] == 'Mumbai Indians') | (df1['team2'] == "Mumbai Indians")]

# %%
mi
# Out:
#            id   season        city        date match_type player_of_match  \
# 3      335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 7      335989  2007/08     Chennai  2008-04-23     League       ML Hayden
# 9      335991  2007/08  Chandigarh  2008-04-25     League   KC Sangakkara
# 12     335994  2007/08      Mumbai  2008-04-27     League    AC Gilchrist
# 15     335997  2007/08     Kolkata  2008-04-29     League   ST Jayasuriya
# ...       ...      ...         ...         ...        ...             ...
# 1071  1426286     2024     Lucknow  2024-04-30     League      MP Stoinis
# 1074  1426289     2024      Mumbai  2024-05-03     League         VR Iyer
# 1078  1426293     2024      Mumbai  2024-05-06     League        SA Yadav
# 1083  1426298     2024     Kolkata  2024-05-11     League        CV Varun
# 1088  1426305     2024      Mumbai  2024-05-17     League        N Pooran
#
#                                                   venue  \
# ...

# %%
data2 = [mi['winner'] != 'Mumbai Indians']

# %%
res3 = pd.merge(data2 , df2 , left_on ='id' , right_on='match_id' , how = 'inner')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 res3 = pd.merge(data2 , df2 , left_on ='id' , right_on='match_id' , how = 'inner')
#
# File ~\anaconda3\envs\myenv\lib\site-packages\pandas\core\reshape\merge.py:152, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     135 @Substitution("\nleft : DataFrame or named Series")
#     136 @Appender(_merge_doc, indents=0)
#     137 def merge(
#    (...)
#     150     validate: str | None = None,
#     151 ) -> DataFrame:
# --> 152     left_df = _validate_operand(left)
#     153     right_df = _validate_operand(right)
#     154     if how == "cross":
#
# File ~\anaconda3\envs\myenv\lib\site-packages\pandas\core\reshape\merge.py:2692, in _validate_operand(obj)
#    2690     return obj.to_frame()
#    2691 else:
# ...

# %%
merge.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2', 'match_id', 'inning', 'batting_team',
#        'bowling_team', 'over', 'ball', 'batter', 'bowler', 'non_striker',
#        'batsman_runs', 'extra_runs', 'total_runs', 'extras_type', 'is_wicket',
#        'player_dismissed', 'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
# merge[['match_type'] == 'Final']

# %%
def create_final (match_type):
    if match_type == 'Final':
        return 1
    else:
         return 0

# %%
merge['is_final'] = merge['match_type'].apply(create_final)

# %%
merge
# Out:
#              id   season       city        date match_type player_of_match  \
# 0        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 1        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 2        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 3        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 4        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# ...         ...      ...        ...         ...        ...             ...
# 260915  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260916  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260917  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260918  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260919  1426312     2024    Chennai  2024-05-26      Final        MA Starc
#
# ...

# %%
df1.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
merge['matchup'] = merge['batter'] + merge['bowler']

# %%
merge
# Out:
#              id   season       city        date match_type player_of_match  \
# 0        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 1        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 2        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 3        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 4        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# ...         ...      ...        ...         ...        ...             ...
# 260915  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260916  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260917  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260918  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260919  1426312     2024    Chennai  2024-05-26      Final        MA Starc
#
# ...

# %%
merge['ball']
# Out:
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5
#          ..
# 260915    5
# 260916    6
# 260917    1
# 260918    2
# 260919    3
# Name: ball, Length: 260920, dtype: int64

# %%
def apply_co(x):
    if x == 4:
        return 'boundry'
    elif x == 0:
        return 'dot'
    else:
        return 'other'

# %%
merge['merge_type'] = merge['total_runs'].apply(apply_co)

# %%
merge
# Out:
#              id   season       city        date match_type player_of_match  \
# 0        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 1        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 2        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 3        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 4        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# ...         ...      ...        ...         ...        ...             ...
# 260915  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260916  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260917  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260918  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260919  1426312     2024    Chennai  2024-05-26      Final        MA Starc
#
# ...

# %%
merge['over']
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#           ..
# 260915     9
# 260916     9
# 260917    10
# 260918    10
# 260919    10
# Name: over, Length: 260920, dtype: int64

# %%
def f(x):
    if x <= 6:
        return True
    else:
        False

# %%
merge['powerplay_ball'] = merge['over'].apply(f)

# %%
merge
# Out:
#              id   season       city        date match_type player_of_match  \
# 0        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 1        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 2        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 3        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 4        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# ...         ...      ...        ...         ...        ...             ...
# 260915  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260916  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260917  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260918  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260919  1426312     2024    Chennai  2024-05-26      Final        MA Starc
#
# ...

# %%
merge['is_wicket'].unique
# Out:
# <bound method Series.unique of 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 260915    0
# 260916    0
# 260917    0
# 260918    0
# 260919    0
# Name: is_wicket, Length: 260920, dtype: int64>

# %%
merge['inning'].unique()
# Out:
# array([1, 2, 3, 4, 5, 6], dtype=int64)

# %%
merge.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2', 'match_id', 'inning', 'batting_team',
#        'bowling_team', 'over', 'ball', 'batter', 'bowler', 'non_striker',
#        'batsman_runs', 'extra_runs', 'total_runs', 'extras_type', 'is_wicket',
#        'player_dismissed', 'dismissal_kind', 'fielder', 'is_final', 'matchup',
#        'merge_type', 'powerplay_ball'],
#       dtype='object')

# %%
def fx(x):
    if x ==1:
        return 'first_inning'
    else:
        return 'second_inning'

# %%
merge['inning_type'] = merge['inning'].apply(fx)

# %%
merge
# Out:
#              id   season       city        date match_type player_of_match  \
# 0        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 1        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 2        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 3        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 4        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# ...         ...      ...        ...         ...        ...             ...
# 260915  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260916  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260917  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260918  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260919  1426312     2024    Chennai  2024-05-26      Final        MA Starc
#
# ...

# %%
merge.shape[1]
# Out:
# 42
