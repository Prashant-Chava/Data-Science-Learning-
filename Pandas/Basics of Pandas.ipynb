# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %% [markdown]
# ### dictionry to dataframe

# %%
data = {
    'date': [ '1/1/2025', '1/2/2025', "1/3/2025", "1/4/2025", "1/5/2025"],
    'city': ['pune', "bangelore", 'nashik', 'mumbai', 'delhi'],
    'temp':[ 23,24,25,30,25],
    'windspeed': [ 10,11,12,13,14]
}

# %%
data
# Out:
# {'date': ['1/1/2025', '1/2/2025', '1/3/2025', '1/4/2025', '1/5/2025'],
#  'city': ['pune', 'bangelore', 'nashik', 'mumbai', 'delhi'],
#  'temp': [23, 24, 25, 30, 25],
#  'windspeed': [10, 11, 12, 13, 14]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#        date       city  temp  windspeed
# 0  1/1/2025       pune    23         10
# 1  1/2/2025  bangelore    24         11
# 2  1/3/2025     nashik    25         12
# 3  1/4/2025     mumbai    30         13
# 4  1/5/2025      delhi    25         14

# %% [markdown]
# ### list to dataframe

# %%
data1 = [
    {"date":'1/1/2025',"city":'pune','temp':30,'windspeed':10},
    {"date":'1/2/2025',"city":'mumbai','temp':40,'windspeed':11},
    {"date":'1/3/2025',"city":'banglore','temp':25,'windspeed':12},
    {"date":'1/1/2025',"city":'pune','temp':30,'windspeed':10},
    {"date":'1/1/2025',"city":'pune','temp':30,'windspeed':10},
]

# %%
data1
# Out:
# [{'date': '1/1/2025', 'city': 'pune', 'temp': 30, 'windspeed': 10},
#  {'date': '1/2/2025', 'city': 'mumbai', 'temp': 40, 'windspeed': 11},
#  {'date': '1/3/2025', 'city': 'banglore', 'temp': 25, 'windspeed': 12},
#  {'date': '1/1/2025', 'city': 'pune', 'temp': 30, 'windspeed': 10},
#  {'date': '1/1/2025', 'city': 'pune', 'temp': 30, 'windspeed': 10}]

# %%
df1 = pd.DataFrame(data1)

# %%
df1
# Out:
#        date      city  temp  windspeed
# 0  1/1/2025      pune    30         10
# 1  1/2/2025    mumbai    40         11
# 2  1/3/2025  banglore    25         12
# 3  1/1/2025      pune    30         10
# 4  1/1/2025      pune    30         10

# %% [markdown]
# ### list of list

# %%
data3 = [
    ['1/1/2025', 'pune', 30, 11],
    ['1/2/2025', 'mumbai', 40 ,13],
    ['1/3/2025', 'banglore', 35, 10],
    ['1/4/2025', 'nashik', 33, 11],
    ['1/5/2025', 'delhi', 31, 12]
]

# %%
df3 = pd.DataFrame(data3 , columns=['Date','city','temperature','windspeed'])

# %%
df3
# Out:
#        Date      city  temperature  windspeed
# 0  1/1/2025      pune           30         11
# 1  1/2/2025    mumbai           40         13
# 2  1/3/2025  banglore           35         10
# 3  1/4/2025    nashik           33         11
# 4  1/5/2025     delhi           31         12

# %%
df4 = pd.read_csv(r'iris.csv')

# %%
df4
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df4.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df4.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df4.head(2) # first  2 rows
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
df4.tail(3)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
### random data riws from the dataset

# %%
df4.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 97            6.2          2.9           4.3          1.3  versicolor
# 127           6.1          3.0           4.9          1.8   virginica
# 143           6.8          3.2           5.9          2.3   virginica
# 101           5.8          2.7           5.1          1.9   virginica
# 79            5.7          2.6           3.5          1.0  versicolor

# %%
df4.sample(4)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 131           7.9          3.8           6.4          2.0   virginica
# 105           7.6          3.0           6.6          2.1   virginica
# 65            6.7          3.1           4.4          1.4  versicolor
# 62            6.0          2.2           4.0          1.0  versicolor

# %%
df4.ndim
# Out:
# 2

# %%
df4.shape
# Out:
# (150, 5)

# %%
df4.shape[0]
# Out:
# 150

# %%
df4.shape[1]
# Out:
# 5

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df4.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df['date']
# Out:
# 0    1/1/2025
# 1    1/2/2025
# 2    1/3/2025
# 3    1/4/2025
# 4    1/5/2025
# Name: date, dtype: object

# %%
df.date
# Out:
# 0    1/1/2025
# 1    1/2/2025
# 2    1/3/2025
# 3    1/4/2025
# 4    1/5/2025
# Name: date, dtype: object

# %%
df[["date", "city"]]
# Out:
#        date       city
# 0  1/1/2025       pune
# 1  1/2/2025  bangelore
# 2  1/3/2025     nashik
# 3  1/4/2025     mumbai
# 4  1/5/2025      delhi

# %%
df[['date','city','temp']]
# Out:
#        date       city  temp
# 0  1/1/2025       pune    23
# 1  1/2/2025  bangelore    24
# 2  1/3/2025     nashik    25
# 3  1/4/2025     mumbai    30
# 4  1/5/2025      delhi    25

# %%
df['temp'].max()
# Out:
# 30

# %%
df['temp'].min()
# Out:
# 23

# %%
#get tht row where temp is max

# %%
df
# Out:
#        date       city  temp  windspeed
# 0  1/1/2025       pune    23         10
# 1  1/2/2025  bangelore    24         11
# 2  1/3/2025     nashik    25         12
# 3  1/4/2025     mumbai    30         13
# 4  1/5/2025      delhi    25         14

# %%
df[df['temp'] == df['temp'].max()]
# Out:
#        date    city  temp  windspeed
# 3  1/4/2025  mumbai    30         13

# %%
df[df['temp'] == df['temp'].min()]
# Out:
#        date  city  temp  windspeed
# 0  1/1/2025  pune    23         10

# %%
df['city'][df['temp'] == df['temp'].max()]
# Out:
# 3    mumbai
# Name: city, dtype: object

# %%
df['temp'] > 28
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# Name: temp, dtype: bool

# %%
df[df['temp'] > 28]
# Out:
#        date    city  temp  windspeed
# 3  1/4/2025  mumbai    30         13

# %%
df[(df['temp'] > 28) & (df['windspeed'] > 10)]
# Out:
#        date    city  temp  windspeed
# 3  1/4/2025  mumbai    30         13

# %%
df4
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df4['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df4['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_built_with_meson',
#  '_config',
# ...

# %%
df
# Out:
#        date       city  temp  windspeed
# 0  1/1/2025       pune    23         10
# 1  1/2/2025  bangelore    24         11
# 2  1/3/2025     nashik    25         12
# 3  1/4/2025     mumbai    30         13
# 4  1/5/2025      delhi    25         14

# %%
df['city'].value_counts()
# Out:
# city
# pune         1
# bangelore    1
# nashik       1
# mumbai       1
# delhi        1
# Name: count, dtype: int64

# %%
df['city'].count()
# Out:
# 5

# %%
df['city'].unique()
# Out:
# array(['pune', 'bangelore', 'nashik', 'mumbai', 'delhi'], dtype=object)

# %%
setosa = df4[df4['species'] == 'setosa']

# %%
setosa
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
versicolor = df4[df4['species'] == 'versicolor']

# %%
versicolor
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor
# 55           5.7          2.8           4.5          1.3  versicolor
# 56           6.3          3.3           4.7          1.6  versicolor
# 57           4.9          2.4           3.3          1.0  versicolor
# 58           6.6          2.9           4.6          1.3  versicolor
# 59           5.2          2.7           3.9          1.4  versicolor
# 60           5.0          2.0           3.5          1.0  versicolor
# 61           5.9          3.0           4.2          1.5  versicolor
# 62           6.0          2.2           4.0          1.0  versicolor
# ...

# %%
virginica = df4[df4['species'] == 'virginica']

# %%
virginica
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 100           6.3          3.3           6.0          2.5  virginica
# 101           5.8          2.7           5.1          1.9  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 103           6.3          2.9           5.6          1.8  virginica
# 104           6.5          3.0           5.8          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 106           4.9          2.5           4.5          1.7  virginica
# 107           7.3          2.9           6.3          1.8  virginica
# 108           6.7          2.5           5.8          1.8  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 110           6.5          3.2           5.1          2.0  virginica
# 111           6.4          2.7           5.3          1.9  virginica
# 112           6.8          3.0           5.5          2.1  virginica
# ...
