# %% [markdown]
# ## Day 2 Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('laptops.csv',encoding="latin-1")

# %%
df
# Out:
#      Manufacturer                           Model Name            Category  \
# 0           Apple                          MacBook Pro           Ultrabook
# 1           Apple                          Macbook Air           Ultrabook
# 2              HP                               250 G6            Notebook
# 3           Apple                          MacBook Pro           Ultrabook
# 4           Apple                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1298       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1299       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1300       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1301           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#      Screen Size                                      Screen  \
# ...

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (1303, 13)

# %%
df.shape[0]
# Out:
# 1303

# %%
df.shape[1]
# Out:
# 13

# %%
df.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# ...

# %%
# to drop ny rows or columns from dataset

# df.drop(columns=['unnamed:0'], inplace =True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              1303 non-null   object
#  1   Model Name                1303 non-null   object
#  2   Category                  1303 non-null   object
#  3   Screen Size               1303 non-null   object
#  4   Screen                    1303 non-null   object
#  5   CPU                       1303 non-null   object
#  6   RAM                       1303 non-null   object
#  7    Storage                  1303 non-null   object
#  8   GPU                       1303 non-null   object
#  9   Operating System          1303 non-null   object
#  10  Operating System Version  1133 non-null   object
#  11  Weight                    1303 non-null   object
#  12  Price (Euros)             1303 non-null   object
# dtypes: object(13)
# memory usage: 132.5+ KB

# %%
df['RAM']
# Out:
# 0        8GB
# 1        8GB
# 2        8GB
# 3       16GB
# 4        8GB
#         ...
# 1298     4GB
# 1299    16GB
# 1300     2GB
# 1301     6GB
# 1302     4GB
# Name: RAM, Length: 1303, dtype: object

# %%
dir(df)
# Out:
# ['CPU',
#  'Category',
#  'GPU',
#  'Manufacturer',
#  'RAM',
#  'Screen',
#  'T',
#  'Weight',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
# ...

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model Name', 'Category', 'Screen Size', 'Screen',
#        'CPU', 'RAM', ' Storage', 'GPU', 'Operating System',
#        'Operating System Version', 'Weight', 'Price (Euros)'],
#       dtype='object')

# %%
df['RAM'] = df['RAM'].str.replace('GB',"")

# %%
df['RAM']
# Out:
# 0        8
# 1        8
# 2        8
# 3       16
# 4        8
#         ..
# 1298     4
# 1299    16
# 1300     2
# 1301     6
# 1302     4
# Name: RAM, Length: 1303, dtype: object

# %%
df['RAM'] = df['RAM'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              1303 non-null   object
#  1   Model Name                1303 non-null   object
#  2   Category                  1303 non-null   object
#  3   Screen Size               1303 non-null   object
#  4   Screen                    1303 non-null   object
#  5   CPU                       1303 non-null   object
#  6   RAM                       1303 non-null   int32
#  7    Storage                  1303 non-null   object
#  8   GPU                       1303 non-null   object
#  9   Operating System          1303 non-null   object
#  10  Operating System Version  1133 non-null   object
#  11  Weight                    1303 non-null   object
#  12  Price (Euros)             1303 non-null   object
# dtypes: int32(1), object(12)
# ...

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model Name', 'Category', 'Screen Size', 'Screen',
#        'CPU', 'RAM', ' Storage', 'GPU', 'Operating System',
#        'Operating System Version', 'Weight', 'Price (Euros)'],
#       dtype='object')

# %%
df['Weight']
# Out:
# 0       1.37kg
# 1       1.34kg
# 2       1.86kg
# 3       1.83kg
# 4       1.37kg
#          ...
# 1298     1.8kg
# 1299     1.3kg
# 1300     1.5kg
# 1301    2.19kg
# 1302     2.2kg
# Name: Weight, Length: 1303, dtype: object

# %%
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df['Weight']
# Out:
# 0       1.37
# 1       1.34
# 2       1.86
# 3       1.83
# 4       1.37
#         ...
# 1298     1.8
# 1299     1.3
# 1300     1.5
# 1301    2.19
# 1302     2.2
# Name: Weight, Length: 1303, dtype: object

# %%
df[df['Weight'].str.contains('[^0-9\.]', regex=True)]
# Out:
#      Manufacturer         Model Name Category Screen Size  \
# 1061         Asus  Rog G752VL-GC088D   Gaming       17.3"
#
#                            Screen                          CPU  RAM  Storage  \
# 1061  IPS Panel Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz   16  1TB HDD
#
#                           GPU Operating System Operating System Version  \
# 1061  Nvidia GeForce GTX 965M            No OS                      NaN
#
#      Weight Price (Euros)
# 1061     4s        998,00

# %%
# replace the 4s to 4.5

# %%
#df.loc[] 
# it is used to access the specific row or column from the dataset 
# we are changing the 4s to 4.5 using the loc methos

# df.loc[condition , column/row]

# %%
df.loc[df['Weight'] == '4s' , 'Weight'] = '4.5'

# %%
df[df['Weight'].str.contains('[^0-9\.]', regex=True)]
# Out:
# Empty DataFrame
# Columns: [Manufacturer, Model Name, Category, Screen Size, Screen, CPU, RAM,  Storage, GPU, Operating System, Operating System Version, Weight, Price (Euros)]
# Index: []

# %%
# now its change
# now we are going to make th whole values as float of the weight column

# %%
df['Weight'] = df["Weight"].astype("float")

# %%
df['Weight']
# Out:
# 0       1.37
# 1       1.34
# 2       1.86
# 3       1.83
# 4       1.37
#         ...
# 1298    1.80
# 1299    1.30
# 1300    1.50
# 1301    2.19
# 1302    2.20
# Name: Weight, Length: 1303, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              1303 non-null   object
#  1   Model Name                1303 non-null   object
#  2   Category                  1303 non-null   object
#  3   Screen Size               1303 non-null   object
#  4   Screen                    1303 non-null   object
#  5   CPU                       1303 non-null   object
#  6   RAM                       1303 non-null   int32
#  7    Storage                  1303 non-null   object
#  8   GPU                       1303 non-null   object
#  9   Operating System          1303 non-null   object
#  10  Operating System Version  1133 non-null   object
#  11  Weight                    1303 non-null   float64
#  12  Price (Euros)             1303 non-null   object
# dtypes: float64(1), int32(1), object(11)
# ...

# %%
# also changing the price columns to float

# %%
df["Price (Euros)"]
# Out:
# 0       1339,69
# 1        898,94
# 2        575,00
# 3       2537,45
# 4       1803,60
#          ...
# 1298     638,00
# 1299    1499,00
# 1300     229,00
# 1301     764,00
# 1302     369,00
# Name: Price (Euros), Length: 1303, dtype: object

# %%
df['Price (Euros)'] = df['Price (Euros)'].str.replace(',' , '')

# %%
df['Price (Euros)']
# Out:
# 0       133969
# 1        89894
# 2        57500
# 3       253745
# 4       180360
#          ...
# 1298     63800
# 1299    149900
# 1300     22900
# 1301     76400
# 1302     36900
# Name: Price (Euros), Length: 1303, dtype: object

# %%
df["Price (Euros)"] = df["Price (Euros)"].astype("float")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              1303 non-null   object
#  1   Model Name                1303 non-null   object
#  2   Category                  1303 non-null   object
#  3   Screen Size               1303 non-null   object
#  4   Screen                    1303 non-null   object
#  5   CPU                       1303 non-null   object
#  6   RAM                       1303 non-null   int32
#  7    Storage                  1303 non-null   object
#  8   GPU                       1303 non-null   object
#  9   Operating System          1303 non-null   object
#  10  Operating System Version  1133 non-null   object
#  11  Weight                    1303 non-null   float64
#  12  Price (Euros)             1303 non-null   float64
# dtypes: float64(2), int32(1), object(10)
# ...

# %%
data = {
    'name' : ['prashant','mayur', 'radhika', 'tushar', 'pratiksha'],
    'gender' : ['male', 'male', 'female', 'male', 'female'],
    'city': ['chalisgaon', 'akola', 'jalgaon', 'chalisgaon', 'pune']
}

# %%
df2 = pd.DataFrame(data)

# %%
df2
# Out:
#         name  gender        city
# 0   prashant    male  chalisgaon
# 1      mayur    male       akola
# 2    radhika  female     jalgaon
# 3     tushar    male  chalisgaon
# 4  pratiksha  female        pune

# %%
# function to convert convert the male to 1 and female to 0

# %%
def convert(x):
    if x == 'male':
        return 1
    else:
        return 0

# %%
df2['gender'] = df2['gender'].apply(convert)

# %%
df2
# Out:
#         name  gender        city
# 0   prashant       1  chalisgaon
# 1      mayur       1       akola
# 2    radhika       0     jalgaon
# 3     tushar       1  chalisgaon
# 4  pratiksha       0        pune

# %%
df.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU  RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz    8
# 1                            1440x900        Intel Core i5 1.8GHz    8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz    8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz   16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz    8
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# ...

# %%
df.rename(columns =  {'Operating System': 'OpSys'} , inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              1303 non-null   object
#  1   Model Name                1303 non-null   object
#  2   Category                  1303 non-null   object
#  3   Screen Size               1303 non-null   object
#  4   Screen                    1303 non-null   object
#  5   CPU                       1303 non-null   object
#  6   RAM                       1303 non-null   int32
#  7    Storage                  1303 non-null   object
#  8   GPU                       1303 non-null   object
#  9   OpSys                     1303 non-null   object
#  10  Operating System Version  1133 non-null   object
#  11  Weight                    1303 non-null   float64
#  12  Price (Euros)             1303 non-null   float64
# dtypes: float64(2), int32(1), object(10)
# ...

# %%
df['OpSys'].unique()
# Out:
# array(['macOS', 'No OS', 'Windows', 'Mac OS', 'Linux', 'Android',
#        'Chrome OS'], dtype=object)

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows      1125
# No OS          66
# Linux          62
# Chrome OS      27
# macOS          13
# Mac OS          8
# Android         2
# Name: count, dtype: int64

# %%
# converting the cateory of the ops

# %%
def convert_Category(x):
    if x=='macOS' or x=='Mac OS':
        return 'mac'
    else:
        return x

# %%
df['OpSys'] = df['OpSys'].apply(convert_Category)

# %%
df['OpSys'].unique()
# Out:
# array(['mac', 'No OS', 'Windows', 'Linux', 'Android', 'Chrome OS'],
#       dtype=object)

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows      1125
# No OS          66
# Linux          62
# Chrome OS      27
# mac            21
# Android         2
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU  RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz    8
# 1                            1440x900        Intel Core i5 1.8GHz    8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz    8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz   16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz    8
#
#                Storage                           GPU  OpSys  \
# 0            128GB SSD  Intel Iris Plus Graphics 640    mac
# 1  128GB Flash Storage        Intel HD Graphics 6000    mac
# ...

# %%
df['CPU']
# Out:
# 0            [Intel, Core, i5]
# 1            [Intel, Core, i5]
# 2            [Intel, Core, i5]
# 3            [Intel, Core, i7]
# 4            [Intel, Core, i5]
#                  ...
# 1298         [Intel, Core, i7]
# 1299         [Intel, Core, i7]
# 1300    [Intel, Celeron, Dual]
# 1301         [Intel, Core, i7]
# 1302    [Intel, Celeron, Dual]
# Name: CPU, Length: 1303, dtype: object

# %%
# converting the cpu long name into short

# %%
def convert_cpu(x):
    words = x.split()
    first_three = words[0:3]
    return " ".join(first_three)

# %%
# df["CPU"] = df["CPU"].apply(convert_cpu)

# %%
df['CPU']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              1303 non-null   object
#  1   Model Name                1303 non-null   object
#  2   Category                  1303 non-null   object
#  3   Screen Size               1303 non-null   object
#  4   Screen                    1303 non-null   object
#  5   CPU                       1303 non-null   object
#  6   RAM                       1303 non-null   int32
#  7    Storage                  1303 non-null   object
#  8   GPU                       1303 non-null   object
#  9   OpSys                     1303 non-null   object
#  10  Operating System Version  1133 non-null   object
#  11  Weight                    1303 non-null   float64
#  12  Price (Euros)             1303 non-null   float64
# dtypes: float64(2), int32(1), object(10)
# ...

# %%
df['CPU']
# Out:
# 0            [Intel, Core, i5]
# 1            [Intel, Core, i5]
# 2            [Intel, Core, i5]
# 3            [Intel, Core, i7]
# 4            [Intel, Core, i5]
#                  ...
# 1298         [Intel, Core, i7]
# 1299         [Intel, Core, i7]
# 1300    [Intel, Celeron, Dual]
# 1301         [Intel, Core, i7]
# 1302    [Intel, Celeron, Dual]
# Name: CPU, Length: 1303, dtype: object

# %%
# BY MISTAKE WE CONVERT THE NAME INTO A LIST BUT WE WANT INTO A STR

# %%
# SO

df['CPU'] = df['CPU'].apply(lambda x: " ".join(x))

# %%
df['CPU']
# Out:
# 0            Intel Core i5
# 1            Intel Core i5
# 2            Intel Core i5
# 3            Intel Core i7
# 4            Intel Core i5
#                ...
# 1298         Intel Core i7
# 1299         Intel Core i7
# 1300    Intel Celeron Dual
# 1301         Intel Core i7
# 1302    Intel Celeron Dual
# Name: CPU, Length: 1303, dtype: object

# %%
df['CPU'].unique()
# Out:
# array(['Intel Core i5', 'Intel Core i7', 'AMD A9-Series 9420',
#        'Intel Core i3', 'Intel Core M', 'Intel Atom x5-Z8350',
#        'AMD E-Series E2-9000e', 'Intel Atom x5-Z8300',
#        'AMD E-Series E2-6110', 'AMD A6-Series 9220', 'Intel Celeron Dual',
#        'AMD Ryzen 1700', 'Intel Pentium Quad', 'Intel Atom x5-Z8550',
#        'AMD FX 9830P', 'AMD E-Series 6110', 'Intel Xeon E3-1505M',
#        'AMD E-Series 9000e', 'AMD A10-Series A10-9620P',
#        'AMD A6-Series A6-9220', 'AMD A10-Series 9600P',
#        'AMD A8-Series 7410', 'AMD A12-Series 9720P', 'Intel Celeron Quad',
#        'AMD Ryzen 1600', 'AMD A10-Series 9620P', 'AMD E-Series 7110',
#        'AMD A9-Series A9-9420', 'Intel Xeon E3-1535M',
#        'AMD E-Series E2-9000', 'AMD A6-Series 7310', 'Intel Atom Z8350',
#        'Intel Pentium Dual', 'AMD A12-Series 9700P', 'AMD A4-Series 7210',
#        'AMD FX 8800P', 'Intel Atom X5-Z8350', 'Samsung Cortex A72&A53',
# ...

# %%
df['CPU'].value_counts()
# Out:
# CPU
# Intel Core i7               527
# Intel Core i5               423
# Intel Core i3               136
# Intel Celeron Dual           80
# Intel Pentium Quad           27
# Intel Core M                 19
# AMD A9-Series 9420           12
# Intel Celeron Quad            8
# AMD A6-Series 9220            8
# AMD A12-Series 9720P          7
# Intel Atom x5-Z8350           5
# AMD A8-Series 7410            4
# Intel Atom x5-Z8550           4
# Intel Pentium Dual            3
# AMD A9-Series 9410            3
# AMD Ryzen 1700                3
# AMD A9-Series A9-9420         2
# AMD A10-Series 9620P          2
# Intel Atom X5-Z8350           2
# AMD E-Series E2-9000e         2
# Intel Xeon E3-1535M           2
# Intel Xeon E3-1505M           2
# AMD E-Series 7110             2
# AMD A10-Series 9600P          2
# AMD A6-Series A6-9220         2
# AMD A10-Series A10-9620P      2
# AMD Ryzen 1600                1
# Intel Atom x5-Z8300           1
# AMD E-Series E2-6110          1
# ...

# %%
# name processor

# %%
def name_processor(x):
    if "Intel" in x:
        return "Intel"
    elif "AMD" in x:
        return "AMD"
    else:
        return "other"

# %%
df['CPU'] = df['CPU'].apply(name_processor)

# %%
df['CPU']
# Out:
# 0       Intel
# 1       Intel
# 2       Intel
# 3       Intel
# 4       Intel
#         ...
# 1298    Intel
# 1299    Intel
# 1300    Intel
# 1301    Intel
# 1302    Intel
# Name: CPU, Length: 1303, dtype: object

# %%
df['CPU'].value_counts()
# Out:
# CPU
# Intel    1240
# AMD        62
# other       1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen    CPU  RAM              Storage  \
# 0  IPS Panel Retina Display 2560x1600  Intel    8            128GB SSD
# 1                            1440x900  Intel    8  128GB Flash Storage
# 2                   Full HD 1920x1080  Intel    8            256GB SSD
# 3  IPS Panel Retina Display 2880x1800  Intel   16            512GB SSD
# 4  IPS Panel Retina Display 2560x1600  Intel    8            256GB SSD
#
#                             GPU  OpSys Operating System Version  Weight  \
# 0  Intel Iris Plus Graphics 640    mac                      NaN    1.37
# 1        Intel HD Graphics 6000    mac                      NaN    1.34
# ...

# %%
df['Operating System Version']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1298     10
# 1299     10
# 1300     10
# 1301     10
# 1302     10
# Name: Operating System Version, Length: 1303, dtype: object

# %%
df.drop(columns = ['Operating System Version'] , inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Manufacturer   1303 non-null   object
#  1   Model Name     1303 non-null   object
#  2   Category       1303 non-null   object
#  3   Screen Size    1303 non-null   object
#  4   Screen         1303 non-null   object
#  5   CPU            1303 non-null   object
#  6   RAM            1303 non-null   int32
#  7    Storage       1303 non-null   object
#  8   GPU            1303 non-null   object
#  9   OpSys          1303 non-null   object
#  10  Weight         1303 non-null   float64
#  11  Price (Euros)  1303 non-null   float64
# dtypes: float64(2), int32(1), object(9)
# memory usage: 117.2+ KB

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model Name', 'Category', 'Screen Size', 'Screen',
#        'CPU', 'RAM', ' Storage', 'GPU', 'OpSys', 'Weight', 'Price (Euros)'],
#       dtype='object')

# %%
df['GPU']
# Out:
# 0       Intel Iris Plus Graphics 640
# 1             Intel HD Graphics 6000
# 2              Intel HD Graphics 620
# 3                 AMD Radeon Pro 455
# 4       Intel Iris Plus Graphics 650
#                     ...
# 1298           Intel HD Graphics 520
# 1299           Intel HD Graphics 520
# 1300               Intel HD Graphics
# 1301              AMD Radeon R5 M330
# 1302               Intel HD Graphics
# Name: GPU, Length: 1303, dtype: object

# %%
df['GPU'].unique()
# Out:
# array(['Intel Iris Plus Graphics 640', 'Intel HD Graphics 6000',
#        'Intel HD Graphics 620', 'AMD Radeon Pro 455',
#        'Intel Iris Plus Graphics 650', 'AMD Radeon R5',
#        'Intel Iris Pro Graphics', 'Nvidia GeForce MX150',
#        'Intel UHD Graphics 620', 'Intel HD Graphics 520',
#        'AMD Radeon Pro 555', 'AMD Radeon R5 M430',
#        'Intel HD Graphics 615', 'AMD Radeon Pro 560',
#        'Nvidia GeForce 940MX', 'Intel HD Graphics 400',
#        'Nvidia GeForce GTX 1050', 'AMD Radeon R2', 'AMD Radeon 530',
#        'Nvidia GeForce 930MX', 'Intel HD Graphics',
#        'Intel HD Graphics 500', 'Nvidia GeForce 930MX ',
#        'Nvidia GeForce GTX 1060', 'Nvidia GeForce 150MX',
#        'Intel Iris Graphics 540', 'AMD Radeon RX 580',
#        'Nvidia GeForce 920MX', 'AMD Radeon R4 Graphics', 'AMD Radeon 520',
#        'Nvidia GeForce GTX 1070', 'Nvidia GeForce GTX 1050 Ti',
#        'Nvidia GeForce MX130', 'AMD R4 Graphics',
# ...

# %%
def convert_gpu(x):
    if "Intel" in x:
        return "Intel"
    elif "Nvidia" in x:
        return "Nvidia"
    else:
        return "other"

# %%
df['GPU'] = df['GPU'].apply(convert_gpu)

# %%
df['GPU'].unique()
# Out:
# array(['Intel', 'other', 'Nvidia'], dtype=object)

# %%
df['GPU'].value_counts()
# Out:
# GPU
# Intel     722
# Nvidia    400
# other     181
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen    CPU  RAM              Storage    GPU  \
# 0  IPS Panel Retina Display 2560x1600  Intel    8            128GB SSD  Intel
# 1                            1440x900  Intel    8  128GB Flash Storage  Intel
# 2                   Full HD 1920x1080  Intel    8            256GB SSD  Intel
# 3  IPS Panel Retina Display 2880x1800  Intel   16            512GB SSD  other
# 4  IPS Panel Retina Display 2560x1600  Intel    8            256GB SSD  Intel
#
#    OpSys  Weight  Price (Euros)
# 0    mac    1.37       133969.0
# 1    mac    1.34        89894.0
# 2  No OS    1.86        57500.0
# 3    mac    1.83       253745.0
# ...

# %%
df.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen    CPU  RAM              Storage    GPU  \
# 0  IPS Panel Retina Display 2560x1600  Intel    8            128GB SSD  Intel
# 1                            1440x900  Intel    8  128GB Flash Storage  Intel
# 2                   Full HD 1920x1080  Intel    8            256GB SSD  Intel
# 3  IPS Panel Retina Display 2880x1800  Intel   16            512GB SSD  other
# 4  IPS Panel Retina Display 2560x1600  Intel    8            256GB SSD  Intel
#
#    OpSys  Weight  Price (Euros)
# 0    mac    1.37       133969.0
# 1    mac    1.34        89894.0
# 2  No OS    1.86        57500.0
# 3    mac    1.83       253745.0
# ...

# %% [markdown]
# ## Day 3

# %%
df.isnull()
# Out:
#       Manufacturer  Model Name  Category  Screen Size  Screen    CPU    RAM  \
# 0            False       False     False        False   False  False  False
# 1            False       False     False        False   False  False  False
# 2            False       False     False        False   False  False  False
# 3            False       False     False        False   False  False  False
# 4            False       False     False        False   False  False  False
# ...            ...         ...       ...          ...     ...    ...    ...
# 1298         False       False     False        False   False  False  False
# 1299         False       False     False        False   False  False  False
# 1300         False       False     False        False   False  False  False
# 1301         False       False     False        False   False  False  False
# 1302         False       False     False        False   False  False  False
#
#        Storage    GPU  OpSys  Weight  Price (Euros)
# ...

# %%
df.isnull().sum()
# Out:
# Manufacturer     0
# Model Name       0
# Category         0
# Screen Size      0
# Screen           0
# CPU              0
# RAM              0
#  Storage         0
# GPU              0
# OpSys            0
# Weight           0
# Price (Euros)    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 29

# %%
df.describe()
# Out:
#                RAM       Weight  Price (Euros)
# count  1303.000000  1303.000000    1303.000000
# mean      8.382195     2.039117  112368.699156
# std       5.084665     0.666749   69900.904253
# min       2.000000     0.690000   17400.000000
# 25%       4.000000     1.500000   59900.000000
# 50%       8.000000     2.040000   97700.000000
# 75%       8.000000     2.300000  148788.000000
# max      64.000000     4.700000  609900.000000

# %%
data1 = {
    'date' : [1/1/2025, 1/2/2025,1/3/2025, 1/4/2025, 1/5/2025],
    'temp' : [32,43,53,21,42],
    'city': ['chalisgaon', 'akola', 'jalgaon', 'cnashil', 'pune']
}

# %%
data2 = {
    'date' : [1/1/2024, 1/2/2024,1/3/2024, 1/4/2024, 1/5/2024],
    'temp' : [32,44,55,24,42],
    'city': ['chalisgaon', 'akola', 'chalisgaon', 'nashik', 'pune']
}

# %%
df1= pd.DataFrame(data1)

# %%
df2 = pd.DataFrame(data2)

# %%
pd.concat([df1,df2], ignore_index=True)  # row wise
# Out:
#        date  temp        city
# 0  0.000494    32  chalisgaon
# 1  0.000247    44       akola
# 2  0.000165    55  chalisgaon
# 3  0.000124    24      nashik
# 4  0.000099    42        pune
# 5  0.000494    32  chalisgaon
# 6  0.000247    44       akola
# 7  0.000165    55  chalisgaon
# 8  0.000124    24      nashik
# 9  0.000099    42        pune

# %%
pd.concat([df1,df2], axis=1)  # column wise
# Out:
#        date  temp        city      date  temp        city
# 0  0.000494    32  chalisgaon  0.000494    32  chalisgaon
# 1  0.000247    44       akola  0.000247    44       akola
# 2  0.000165    55  chalisgaon  0.000165    55  chalisgaon
# 3  0.000124    24      nashik  0.000124    24      nashik
# 4  0.000099    42        pune  0.000099    42        pune

# %%
pd.megre(df1,df2, how='inner', )

# %%
df3 = pd.read_csv('matches.csv')

# %%
df3
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
# total no of seasons

# %%
total = df3[(df3['team1'] == 'Mumbai Indians')  | (df3['team2'] == 'Mumbai Indians')]
total
# Out:
#            id   season        city        date match_type player_of_match  \
# 3      335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 7      335989  2007/08     Chennai  2008-04-23     League       ML Hayden
# 9      335991  2007/08  Chandigarh  2008-04-25     League   KC Sangakkara
# 12     335994  2007/08      Mumbai  2008-04-27     League    AC Gilchrist
# 15     335997  2007/08     Kolkata  2008-04-29     League   ST Jayasuriya
# ...       ...      ...         ...         ...        ...             ...
# 1071  1426286     2024     Lucknow  2024-04-30     League      MP Stoinis
# 1074  1426289     2024      Mumbai  2024-05-03     League         VR Iyer
# 1078  1426293     2024      Mumbai  2024-05-06     League        SA Yadav
# 1083  1426298     2024     Kolkata  2024-05-11     League        CV Varun
# 1088  1426305     2024      Mumbai  2024-05-17     League        N Pooran
#
#                                                   venue  \
# ...

# %%
df3['season'].count()
# Out:
# 1095

# %%
df3.tail()
# Out:
#            id season       city        date   match_type  player_of_match  \
# 1090  1426307   2024  Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309   2024  Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310   2024  Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311   2024    Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312   2024    Chennai  2024-05-26        Final         MA Starc
#
#                                                   venue  \
# 1090  Rajiv Gandhi International Stadium, Uppal, Hyd...
# 1091                   Narendra Modi Stadium, Ahmedabad
# 1092                   Narendra Modi Stadium, Ahmedabad
# 1093           MA Chidambaram Stadium, Chepauk, Chennai
# 1094           MA Chidambaram Stadium, Chepauk, Chennai
#
#                             team1                  team2          toss_winner  \
# 1090                 Punjab Kings    Sunrisers Hyderabad         Punjab Kings
# ...

# %%
df3['season'].unique()
# Out:
# array(['2007/08', '2009', '2009/10', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2018', '2019', '2020/21', '2021', '2022',
#        '2023', '2024'], dtype=object)

# %%
df3[df3['city'] == 'Chennai']
# Out:
#            id   season     city        date   match_type  player_of_match  \
# 7      335989  2007/08  Chennai  2008-04-23       League        ML Hayden
# 11     335993  2007/08  Chennai  2008-04-26       League         JDP Oram
# 19     336001  2007/08  Chennai  2008-05-02       League         V Sehwag
# 25     336007  2007/08  Chennai  2008-05-06       League     AC Gilchrist
# 30     336013  2007/08  Chennai  2008-05-10       League         L Balaji
# ...       ...      ...      ...         ...          ...              ...
# 1069  1426284     2024  Chennai  2024-04-28       League       RD Gaikwad
# 1072  1426287     2024  Chennai  2024-05-01       League    Harpreet Brar
# 1084  1426299     2024  Chennai  2024-05-12       League  Simarjeet Singh
# 1093  1426311     2024  Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024  Chennai  2024-05-26        Final         MA Starc
#
#                                          venue                team1  \
# ...

# %%
df3[df3['city'] == 'Chennai'].shape[0]
# Out:
# 85

# %%
def count_match(city,x):
    cnt = 0
    for i in city:
        if city == x:
            cnt+=1
    return cnt

# %%
def cnt_city(city):
    x = df3[df3['city'] == 'Chennai'].shape[0]
    return x

# %%
cnt_city("mumbai")
# Out:
# 85

# %%
df3[df3['city'] == 'Mumbai'].shape[0] - df3[df3['winner'] == 'Mumbai Indians'].shape[0]
# Out:
# 29

# %%
def all_matches(city , home_team):
    x =  df3[df3['city'] == city].shape[0] - df3[df3['winner'] == home_team ].shape[0]
    return x

# %%
all_matches('Mumbai',"Mumbai Indians")
# Out:
# 29

# %%
all_matches('Chennai', 'Chennai Super kings ')
# Out:
# 85

# %%
df3[df3['season'] == '2016'].shape[0]
# Out:
# 60

# %%
def cnt_season_wise(season):
    x = df3[df3['season'] == '2016'].shape[0]
    return x

# %%
cnt_season_wise('2016')
# Out:
# 60

# %%
df3['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 144
# Chennai Super Kings            138
# Kolkata Knight Riders          131
# Royal Challengers Bangalore    116
# Rajasthan Royals               112
# Kings XI Punjab                 88
# Sunrisers Hyderabad             88
# Delhi Daredevils                67
# Delhi Capitals                  48
# Deccan Chargers                 29
# Gujarat Titans                  28
# Lucknow Super Giants            24
# Punjab Kings                    24
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Royal Challengers Bengaluru      7
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
df3['toss_winner'].value_counts().idxmax()
# Out:
# 'Mumbai Indians'

# %%
df3[(df3['toss_winner'] == 'Mumbai Indians') & (df3['winner'] == 'toss_winner')]
# Out:
# Empty DataFrame
# Columns: [id, season, city, date, match_type, player_of_match, venue, team1, team2, toss_winner, toss_decision, winner, result, result_margin, target_runs, target_overs, super_over, method, umpire1, umpire2]
# Index: []

# %%
df3[(df3['toss_winner'] == 'Mumbai Indians') & (df3['winner'] == 'Mumbai Indians')]
# Out:
#            id   season            city        date  match_type  \
# 26     336008  2007/08          Mumbai  2008-05-07      League
# 35     336018  2007/08          Mumbai  2008-05-14      League
# 37     336021  2007/08          Mumbai  2008-05-16      League
# 53     336012  2007/08       Bangalore  2008-05-28      League
# 72     392197     2009  Port Elizabeth  2009-04-27      League
# ...       ...      ...             ...         ...         ...
# 1003  1359528     2023          Mumbai  2023-05-09      League
# 1018  1359543     2023          Mumbai  2023-05-21      League
# 1021  1370351     2023         Chennai  2023-05-24  Eliminator
# 1048  1426263     2024          Mumbai  2024-04-11      League
# 1078  1426293     2024          Mumbai  2024-05-06      League
#
#      player_of_match                                     venue  \
# 26           A Nehra                Dr DY Patil Sports Academy
# 35     ST Jayasuriya                          Wankhede Stadium
# ...

# %%
df3[(df3['toss_winner'] != 'Mumbai Indians') & (df3['winner'] == 'Mumbai Indians')].shape[0]
# Out:
# 66

# %%
df3.shape[0]
# Out:
# 1095

# %%
total = df3[(df3['team1'] == 'Mumbai Indians')  | (df3['team2'] == 'Mumbai Indians')]

# %%
total.shape[0]
# Out:
# 261

# %%
total_cnt = total.shape[0]

# %%
total_cnt
# Out:
# 261

# %%
mi_won = total[total['winner'] == 'Mumbai Indians']

# %%
mi_won.shape[0]
# Out:
# 144

# %%
# mi_won/total)*100
mi_won_percent = (len(mi_won) / len(total) ) * 100

# %%
mi_won_percent
# Out:
# 55.172413793103445

# %%
df3['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 144
# Chennai Super Kings            138
# Kolkata Knight Riders          131
# Royal Challengers Bangalore    116
# Rajasthan Royals               112
# Kings XI Punjab                 88
# Sunrisers Hyderabad             88
# Delhi Daredevils                67
# Delhi Capitals                  48
# Deccan Chargers                 29
# Gujarat Titans                  28
# Lucknow Super Giants            24
# Punjab Kings                    24
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Royal Challengers Bengaluru      7
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
df3.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
df3['match_type'].unique()
# Out:
# array(['League', 'Semi Final', 'Final', '3rd Place Play-Off',
#        'Qualifier 1', 'Elimination Final', 'Qualifier 2', 'Eliminator'],
#       dtype=object)

# %%
final = df3[df3['match_type'] == 'Final']

# %%
df3[(df3['match_type'] == 'Final') & (df3['winner'] == "Mumbai Indians")].shape[0]
# Out:
# 5

# %%
df3['match_type'].unique()
# Out:
# array(['League', 'Semi Final', 'Final', '3rd Place Play-Off',
#        'Qualifier 1', 'Elimination Final', 'Qualifier 2', 'Eliminator'],
#       dtype=object)

# %%
final = df3[df3['match_type'] == 'Final'].shape[0]

# %%
final
# Out:
# 17

# %%
df3['winner'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Delhi Daredevils',
#        'Royal Challengers Bangalore', 'Rajasthan Royals',
#        'Kings XI Punjab', 'Deccan Chargers', 'Mumbai Indians',
#        'Pune Warriors', 'Kochi Tuskers Kerala', nan,
#        'Sunrisers Hyderabad', 'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Gujarat Titans', 'Lucknow Super Giants',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
# df3[(df3['match_type'] == 'Final') &

# %%
df3.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
total = df3[df3['match_type'] == 'Final']

# %%
final_wins = total['winner'].value_counts()
final_wins
# Out:
# winner
# Chennai Super Kings      5
# Mumbai Indians           5
# Kolkata Knight Riders    3
# Rajasthan Royals         1
# Deccan Chargers          1
# Sunrisers Hyderabad      1
# Gujarat Titans           1
# Name: count, dtype: int64

# %%
top_team = final_wins.idxmax()
top_team
# Out:
# 'Chennai Super Kings'

# %%
most_win = final_wins.max()
most_win
# Out:
# 5

# %%
top_teams = final_wins[final_wins == most_win]

# %%
top_teams
# Out:
# winner
# Chennai Super Kings    5
# Mumbai Indians         5
# Name: count, dtype: int64

# %%
import pandas as pd

# %%
df2 = pd.read_csv('matches.csv')

# %%
df2.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
data1  = {
    'date': ['1/1/2025','1/2/2025','1/3/2025','1/4/2025','1/5/2025','1/6/2025'],
    'city': ['nashik', 'pune', 'mumbai', 'pune', 'jalgaon','nashik'],
    'temp': [23,43,34,54,26,24]
}

# %%
df = pd.DataFrame(data1)

# %%
df
# Out:
#        date     city  temp
# 0  1/1/2025   nashik    23
# 1  1/2/2025     pune    43
# 2  1/3/2025   mumbai    34
# 3  1/4/2025     pune    54
# 4  1/5/2025  jalgaon    26
# 5  1/6/2025   nashik    24

# %%
g = df.groupby('city')
g

# %%
for city,df_city in g:
    print(city)
    print(df_city)
# Out:
# jalgaon
#        date     city  temp
# 4  1/5/2025  jalgaon    26
# mumbai
#        date    city  temp
# 2  1/3/2025  mumbai    34
# nashik
#        date    city  temp
# 0  1/1/2025  nashik    23
# 5  1/6/2025  nashik    24
# pune
#        date  city  temp
# 1  1/2/2025  pune    43
# 3  1/4/2025  pune    54

# %%
# t = df.groupby('temp').mean()

# %%
g.max()
# Out:
#              date  temp
# city
# jalgaon  1/5/2025    26
# mumbai   1/3/2025    34
# nashik   1/6/2025    24
# pune     1/4/2025    54

# %%
g.min()
# Out:
#              date  temp
# city
# jalgaon  1/5/2025    26
# mumbai   1/3/2025    34
# nashik   1/1/2025    23
# pune     1/2/2025    43

# %%
g.mean(numeric_only=True)
# Out:
#          temp
# city
# jalgaon  26.0
# mumbai   34.0
# nashik   23.5
# pune     48.5

# %%
g.median(numeric_only= True)
# Out:
#          temp
# city
# jalgaon  26.0
# mumbai   34.0
# nashik   23.5
# pune     48.5

# %%
data2 = {
    'date': ['1/1/2025','1/2/2025','1/3/2025','1/4/2025','1/5/2025','1/6/2025'],
    'city': ['nashik', 'pune', 'mumbai', 'pune', 'jalgaon','nashik'],
    'temp': [23,43,34,54,26,24]
}
data3 = {
    'date': ['1/1/2025','1/2/2025','1/3/2025','1/4/2025','1/5/2025','1/6/2025'],
    'city': ['hyderabad', 'delhi', 'delhi', 'nagpur', 'jalgaon','pune'],
    'humedity': [23,43,34,54,26,24]
}

# %%
df2 = pd.DataFrame(data2)
df3 = pd.DataFrame(data3)

# %%
df2
# Out:
#        date     city  temp
# 0  1/1/2025   nashik    23
# 1  1/2/2025     pune    43
# 2  1/3/2025   mumbai    34
# 3  1/4/2025     pune    54
# 4  1/5/2025  jalgaon    26
# 5  1/6/2025   nashik    24

# %%
df3
# Out:
#        date       city  humedity
# 0  1/1/2025  hyderabad        23
# 1  1/2/2025      delhi        43
# 2  1/3/2025      delhi        34
# 3  1/4/2025     nagpur        54
# 4  1/5/2025    jalgaon        26
# 5  1/6/2025       pune        24

# %%
pd.merge(df2,df3,on='city')  # inner join
# Out:
#      date_x     city  temp    date_y  humedity
# 0  1/2/2025     pune    43  1/6/2025        24
# 1  1/4/2025     pune    54  1/6/2025        24
# 2  1/5/2025  jalgaon    26  1/5/2025        26

# %%
import pandas as pd
dff = pd.read_csv('matches.csv')

# %%
dff.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
dff2 = pd.read_csv('deliveries.csv')

# %%
dff2.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
dff.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
dff2.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
m = pd.merge(dff,dff2,left_on='id',right_on='match_id',how='inner')

# %%
m
# Out:
#              id   season       city        date match_type player_of_match  \
# 0        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 1        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 2        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 3        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 4        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# ...         ...      ...        ...         ...        ...             ...
# 260915  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260916  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260917  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260918  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260919  1426312     2024    Chennai  2024-05-26      Final        MA Starc
#
# ...

# %%
dff.shape[0]
# Out:
# 1095

# %%
dff2.shape[0]
# Out:
# 260920

# %%
dir(set)
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %%
diff = len(set(dff2['match_id'])) - len(set(dff['id']))

# %%
diff
# Out:
# 0

# %%
dff.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
dff2.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
# left join gives the records which matches with right table and all the records from the left
left_m = pd.merge(dff,dff2,left_on='id',right_on='match_id',how='left')

# %%
left_m
# Out:
#              id   season       city        date match_type player_of_match  \
# 0        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 1        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 2        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 3        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 4        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# ...         ...      ...        ...         ...        ...             ...
# 260915  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260916  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260917  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260918  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260919  1426312     2024    Chennai  2024-05-26      Final        MA Starc
#
# ...

# %%
right_m = pd.merge(dff,dff2,left_on='id',right_on='match_id',how='right')

# %%
right_m
# Out:
#              id   season       city        date match_type player_of_match  \
# 0        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 1        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 2        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 3        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 4        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# ...         ...      ...        ...         ...        ...             ...
# 260915  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260916  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260917  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260918  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260919  1426312     2024    Chennai  2024-05-26      Final        MA Starc
#
# ...

# %%
# left join gives the records which matches with right table and all the records from the left
left_m = pd.merge(dff,dff2,left_on='id',right_on='match_id',how='left')

# %%
m
# Out:
#              id   season       city        date match_type player_of_match  \
# 0        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 1        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 2        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 3        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 4        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# ...         ...      ...        ...         ...        ...             ...
# 260915  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260916  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260917  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260918  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260919  1426312     2024    Chennai  2024-05-26      Final        MA Starc
#
# ...

# %%
final = dff[dff['match_type'] == 'Final'].shape[0]

# %%
final
# Out:
# 17

# %%
dff.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
dff2.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
dff2.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
dff.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
ans = m[['season','match_type','total_runs']]

# %%
res = ans[ans['match_type'] == 'Final'].sum()

# %%
res
# Out:
# season        2007/082007/082007/082007/082007/082007/082007...
# match_type    FinalFinalFinalFinalFinalFinalFinalFinalFinalF...
# total_runs                                                 5556
# dtype: object

# %%
res['total_runs']
# Out:
# 5556
