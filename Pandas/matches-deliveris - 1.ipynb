# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('matches.csv')
df1 = pd.read_csv('deliveries.csv')

# %%
res1 = df[['id','season']]
res2 = df1[['match_id','batting_team','batsman_runs']]

# %%
result = pd.merge(res1,res2,left_on='id',right_on='match_id',how='inner')

# %%
result
# Out:
#              id   season  match_id           batting_team  batsman_runs
# 0        335982  2007/08    335982  Kolkata Knight Riders             0
# 1        335982  2007/08    335982  Kolkata Knight Riders             0
# 2        335982  2007/08    335982  Kolkata Knight Riders             0
# 3        335982  2007/08    335982  Kolkata Knight Riders             0
# 4        335982  2007/08    335982  Kolkata Knight Riders             0
# ...         ...      ...       ...                    ...           ...
# 260915  1426312     2024   1426312  Kolkata Knight Riders             1
# 260916  1426312     2024   1426312  Kolkata Knight Riders             1
# 260917  1426312     2024   1426312  Kolkata Knight Riders             1
# 260918  1426312     2024   1426312  Kolkata Knight Riders             1
# 260919  1426312     2024   1426312  Kolkata Knight Riders             1
#
# [260920 rows x 5 columns]

# %%
com_six = result[result['batsman_runs']==6]

# %%
com_six
# Out:
#              id   season  match_id           batting_team  batsman_runs
# 10       335982  2007/08    335982  Kolkata Knight Riders             6
# 20       335982  2007/08    335982  Kolkata Knight Riders             6
# 25       335982  2007/08    335982  Kolkata Knight Riders             6
# 60       335982  2007/08    335982  Kolkata Knight Riders             6
# 65       335982  2007/08    335982  Kolkata Knight Riders             6
# ...         ...      ...       ...                    ...           ...
# 260868  1426312     2024   1426312  Kolkata Knight Riders             6
# 260869  1426312     2024   1426312  Kolkata Knight Riders             6
# 260889  1426312     2024   1426312  Kolkata Knight Riders             6
# 260895  1426312     2024   1426312  Kolkata Knight Riders             6
# 260908  1426312     2024   1426312  Kolkata Knight Riders             6
#
# [13051 rows x 5 columns]

# %%
ans = com_six.groupby(['season','batting_team'])['batsman_runs'].count().reset_index()

# %%
ans
# Out:
#       season                 batting_team  batsman_runs
# 0    2007/08          Chennai Super Kings            86
# 1    2007/08              Deccan Chargers            92
# 2    2007/08             Delhi Daredevils            54
# 3    2007/08              Kings XI Punjab            95
# 4    2007/08        Kolkata Knight Riders            76
# ..       ...                          ...           ...
# 141     2024               Mumbai Indians           133
# 142     2024                 Punjab Kings           120
# 143     2024             Rajasthan Royals           112
# 144     2024  Royal Challengers Bengaluru           165
# 145     2024          Sunrisers Hyderabad           178
#
# [146 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
res = df[['city','winner','team1','team2']]

# %%
winner = pd.crosstab(df['winner'],df['city'])

# %%
winner
# Out:
# city                         Abu Dhabi  Ahmedabad  Bangalore  Bengaluru  \
# winner
# Chennai Super Kings                  4          1          4          2
# Deccan Chargers                      0          0          1          0
# Delhi Capitals                       3          4          0          1
# Delhi Daredevils                     0          1          3          0
# Gujarat Lions                        0          0          1          0
# Gujarat Titans                       0          9          0          1
# Kings XI Punjab                      2          1          5          0
# Kochi Tuskers Kerala                 0          0          0          0
# Kolkata Knight Riders                8          3          6          4
# Lucknow Super Giants                 0          0          0          2
# Mumbai Indians                       8          1          8          1
# Pune Warriors                        0          0          0          0
# ...

# %%
# strik rate of a batsman

# %%
strike_rate = df1[['over', 'ball','batter','batsman_runs']]

# %%
ans3 = strike_rate.groupby('over')['batsman_runs']

# %%
t1 = df1[['over', 'ball','batter','batsman_runs']]

# %%
t1
# Out:
#         over  ball       batter  batsman_runs
# 0          0     1   SC Ganguly             0
# 1          0     2  BB McCullum             0
# 2          0     3  BB McCullum             0
# 3          0     4  BB McCullum             0
# 4          0     5  BB McCullum             0
# ...      ...   ...          ...           ...
# 260915     9     5      SS Iyer             1
# 260916     9     6      VR Iyer             1
# 260917    10     1      VR Iyer             1
# 260918    10     2      SS Iyer             1
# 260919    10     3      VR Iyer             1
#
# [260920 rows x 4 columns]

# %%
ans3 = t1.groupby('batter')['batsman_runs'].sum()

# %%
ans3
# Out:
# batter
# A Ashish Reddy     280
# A Badoni           634
# A Chandila           4
# A Chopra            53
# A Choudhary         25
#                   ...
# Yashpal Singh       47
# Younis Khan          3
# Yudhvir Singh       22
# Yuvraj Singh      2754
# Z Khan             117
# Name: batsman_runs, Length: 673, dtype: int64

# %%
ans4 = t1.groupby('batter')['ball'].sum()

# %%
ans4
# Out:
# batter
# A Ashish Reddy     720
# A Badoni          1882
# A Chandila          23
# A Chopra           273
# A Choudhary         71
#                   ...
# Yashpal Singh      250
# Younis Khan         25
# Yudhvir Singh       67
# Yuvraj Singh      8162
# Z Khan             525
# Name: ball, Length: 673, dtype: int64

# %%
result1 = pd.merge(ans3,ans4,left_on='batter',right_on='batter',how='inner')

# %% [raw]
# result1

# %%
result1['strike_rate'] = result1['battsman_runs'] / result1['ball']*100
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\myenv\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'battsman_runs'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[221], line 1
# ...

# %%
powerplay = df1[df1['over'] <= 5]

# %%
ss = df1.powerplay
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260888   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260889   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260890   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260891   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260892   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
# which season had the highest number of scored

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
a1 = df[['id','season']]
a2 = df1[['match_id','total_runs']]

# %%
ress = pd.merge(a1,a2,left_on='id',right_on='match_id',how='inner')

# %%
final = ress.groupby('season')['total_runs'].sum()

# %%
final.sort_values(ascending=False)
# Out:
# season
# 2024       25971
# 2023       25688
# 2022       24395
# 2013       22602
# 2012       22453
# 2011       21154
# 2018       19901
# 2019       19434
# 2020/21    19416
# 2014       18931
# 2009/10    18883
# 2016       18862
# 2017       18786
# 2021       18637
# 2015       18353
# 2007/08    17937
# 2009       16353
# Name: total_runs, dtype: int64

# %%
b1 = df[['id','winner']]
b2 = df1[['match_id','total_runs']]

# %%
res_merge = pd.merge(b1,b2,left_on='id',right_on='match_id',how='inner')

# %%
res_merge.drop(columns = 'match_id', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[334], line 1
# ----> 1 res_merge.drop(columns = 'match_id', inplace=True)
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %%
ress  = pd.merge(df,df1,left_on='id',right_on='match_id',how='inner')

# %%
ress.groupby('match_id')['total_runs'].sum()
# Out:
# match_id
# 335982     304
# 335983     447
# 335984     261
# 335985     331
# 335986     222
#           ...
# 1426307    429
# 1426309    323
# 1426310    346
# 1426311    314
# 1426312    227
# Name: total_runs, Length: 1095, dtype: int64

# %%
abc = ress.sort_values(by='total_runs', ascending=False)

# %%
abc
# Out:
#              id   season       city        date match_type player_of_match  \
# 142451  1082615     2017       Pune  2017-04-22     League        MS Dhoni
# 206718  1254088     2021  Abu Dhabi  2021-10-08     League    Ishan Kishan
# 172778  1178409     2019      Delhi  2019-04-18     League       HH Pandya
# 91264    598060     2013     Mumbai  2013-05-13     League      KA Pollard
# 8850     336021  2007/08     Mumbai  2008-05-16     League      SM Pollock
# ...         ...      ...        ...         ...        ...             ...
# 57469    501267     2011    Kolkata  2011-05-22     League    JEC Franklin
# 100026   733977     2014  Bangalore  2014-05-04     League  AB de Villiers
# 194187  1254060     2021    Chennai  2021-04-11     League          N Rana
# 144399  1082624     2017       Pune  2017-04-29     League     LH Ferguson
# 60239    548313     2012       Pune  2012-04-08     League      MN Samuels
#
# ...

# %%
# 43. Identify the match where the most fell.
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
merge = pd.merge(df,df1,left_on='id',right_on='match_id',how='inner')

# %%
merge
# Out:
#              id   season       city        date match_type player_of_match  \
# 0        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 1        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 2        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 3        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 4        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# ...         ...      ...        ...         ...        ...             ...
# 260915  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260916  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260917  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260918  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 260919  1426312     2024    Chennai  2024-05-26      Final        MA Starc
#
# ...
