# %% [markdown]
# ### Day 4

# %% [markdown]
# ## accessing data

# %%
import pandas as pd

# %%
animals = pd.Series(['cat','dog','elephant','tiger','snake'] , index = [3,9,8,5,4])

# %%
animals
# Out:
# 3         cat
# 9         dog
# 8    elephant
# 5       tiger
# 4       snake
# dtype: object

# %%
# loc refers to index

# %%
animals.loc[3]
# Out:
# 'cat'

# %%
animals.loc[9]
# Out:
# 'dog'

# %%
df = pd.read_csv('laptops.csv' ,  encoding='latin-1')

# %%
df
# Out:
#      Manufacturer                           Model Name            Category  \
# 0           Apple                          MacBook Pro           Ultrabook
# 1           Apple                          Macbook Air           Ultrabook
# 2              HP                               250 G6            Notebook
# 3           Apple                          MacBook Pro           Ultrabook
# 4           Apple                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1298       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1299       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1300       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1301           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#      Screen Size                                      Screen  \
# ...

# %%
df.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# ...

# %%
# df.tail()

# %%
df.loc[3]
# Out:
# Manufacturer                                             Apple
# Model Name                                         MacBook Pro
# Category                                             Ultrabook
# Screen Size                                              15.4"
# Screen                      IPS Panel Retina Display 2880x1800
# CPU                                       Intel Core i7 2.7GHz
# RAM                                                       16GB
#  Storage                                             512GB SSD
# GPU                                         AMD Radeon Pro 455
# Operating System                                         macOS
# Operating System Version                                   NaN
# Weight                                                  1.83kg
# Price (Euros)                                          2537,45
# Name: 3, dtype: object

# %%
# df.iloc[]

# %%
# iloc prefers to  position 
animals
# Out:
# 3         cat
# 9         dog
# 8    elephant
# 5       tiger
# 4       snake
# dtype: object

# %%
animals.iloc[3]
# Out:
# 'tiger'

# %%
df.iloc[3]
# Out:
# Manufacturer                                             Apple
# Model Name                                         MacBook Pro
# Category                                             Ultrabook
# Screen Size                                              15.4"
# Screen                      IPS Panel Retina Display 2880x1800
# CPU                                       Intel Core i7 2.7GHz
# RAM                                                       16GB
#  Storage                                             512GB SSD
# GPU                                         AMD Radeon Pro 455
# Operating System                                         macOS
# Operating System Version                                   NaN
# Weight                                                  1.83kg
# Price (Euros)                                          2537,45
# Name: 3, dtype: object

# %%
animals.iloc[:3]
# Out:
# 3         cat
# 9         dog
# 8    elephant
# dtype: object

# %%
df.iloc[:2]
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
#
#                                Screen                   CPU  RAM  \
# 0  IPS Panel Retina Display 2560x1600  Intel Core i5 2.3GHz  8GB
# 1                            1440x900  Intel Core i5 1.8GHz  8GB
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
#
#   Operating System Version  Weight Price (Euros)
# 0                      NaN  1.37kg       1339,69
# 1                      NaN  1.34kg        898,94

# %%
df.Screen
# Out:
# 0               IPS Panel Retina Display 2560x1600
# 1                                         1440x900
# 2                                Full HD 1920x1080
# 3               IPS Panel Retina Display 2880x1800
# 4               IPS Panel Retina Display 2560x1600
#                            ...
# 1298     IPS Panel Full HD / Touchscreen 1920x1080
# 1299    IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                      1366x768
# 1301                                      1366x768
# 1302                                      1366x768
# Name: Screen, Length: 1303, dtype: object

# %%
df['Screen']
# Out:
# 0               IPS Panel Retina Display 2560x1600
# 1                                         1440x900
# 2                                Full HD 1920x1080
# 3               IPS Panel Retina Display 2880x1800
# 4               IPS Panel Retina Display 2560x1600
#                            ...
# 1298     IPS Panel Full HD / Touchscreen 1920x1080
# 1299    IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                      1366x768
# 1301                                      1366x768
# 1302                                      1366x768
# Name: Screen, Length: 1303, dtype: object

# %%
df['Manufacturer']
# Out:
# 0        Apple
# 1        Apple
# 2           HP
# 3        Apple
# 4        Apple
#          ...
# 1298    Lenovo
# 1299    Lenovo
# 1300    Lenovo
# 1301        HP
# 1302      Asus
# Name: Manufacturer, Length: 1303, dtype: object

# %%
df[df['Manufacturer'] == 'Apple']
# Out:
#      Manufacturer   Model Name   Category Screen Size  \
# 0           Apple  MacBook Pro  Ultrabook       13.3"
# 1           Apple  Macbook Air  Ultrabook       13.3"
# 3           Apple  MacBook Pro  Ultrabook       15.4"
# 4           Apple  MacBook Pro  Ultrabook       13.3"
# 6           Apple  MacBook Pro  Ultrabook       15.4"
# 7           Apple  Macbook Air  Ultrabook       13.3"
# 12          Apple  MacBook Pro  Ultrabook       15.4"
# 14          Apple  MacBook 12"  Ultrabook       12.0"
# 15          Apple  MacBook Pro  Ultrabook       13.3"
# 17          Apple  MacBook Pro  Ultrabook       15.4"
# 26          Apple  MacBook Air  Ultrabook       13.3"
# 34          Apple  MacBook Air  Ultrabook       13.3"
# 45          Apple  MacBook Pro  Ultrabook       13.3"
# 81          Apple  MacBook 12"  Ultrabook       12.0"
# 249         Apple  MacBook Pro  Ultrabook       13.3"
# 270         Apple  MacBook Pro  Ultrabook       13.3"
# ...

# %% [markdown]
# ## selecting and viewing data

# %%
# crosstab is used to combining the data from 2 columns

# %%
pd.crosstab(df['Manufacturer'], df['RAM'])
# Out:
# RAM           12GB  16GB  24GB  2GB  32GB  4GB  64GB  6GB  8GB
# Manufacturer
# Acer             3     4     0    3     0   57     0    3   33
# Apple            0     4     0    0     0    1     0    0   16
# Asus             5    35     2    4     3   45     1    2   61
# Chuwi            0     0     0    0     0    2     0    1    0
# Dell             5    54     0    3     7   63     0    4  161
# Fujitsu          0     0     0    0     0    1     0    0    2
# Google           0     1     0    0     0    0     0    0    2
# HP               6    13     0    5     0   90     0   18  142
# Huawei           0     0     0    0     0    0     0    0    2
# LG               0     1     0    0     0    0     0    0    2
# Lenovo           6    39     1    5     3   89     0   13  141
# MSI              0    31     0    0     1    0     0    0   22
# Mediacom         0     0     0    1     0    6     0    0    0
# Microsoft        0     1     0    0     0    2     0    0    3
# ...

# %%
pd.crosstab(df['Manufacturer'] , df['CPU'])
# Out:
# CPU           AMD A10-Series 9600P 2.4GHz  AMD A10-Series 9620P 2.5GHz  \
# Manufacturer
# Acer                                    0                            1
# Apple                                   0                            0
# Asus                                    0                            0
# Chuwi                                   0                            0
# Dell                                    0                            0
# Fujitsu                                 0                            0
# Google                                  0                            0
# HP                                      1                            1
# Huawei                                  0                            0
# LG                                      0                            0
# Lenovo                                  1                            0
# MSI                                     0                            0
# ...

# %%
df.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# ...

# %%
pd.crosstab(df['Manufacturer'] , df['Storage'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\myenv\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Storage'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 pd.crosstab(df['Manufacturer'] , df['Storage'])
#
# ...

# %%
df.columns.tolist()
# Out:
# ['Manufacturer',
#  'Model Name',
#  'Category',
#  'Screen Size',
#  'Screen',
#  'CPU',
#  'RAM',
#  ' Storage',
#  'GPU',
#  'Operating System',
#  'Operating System Version',
#  'Weight',
#  'Price (Euros)']

# %%
df[' Storage']
# Out:
# 0                 128GB SSD
# 1       128GB Flash Storage
# 2                 256GB SSD
# 3                 512GB SSD
# 4                 256GB SSD
#                ...
# 1298              128GB SSD
# 1299              512GB SSD
# 1300     64GB Flash Storage
# 1301                1TB HDD
# 1302              500GB HDD
# Name:  Storage, Length: 1303, dtype: object

# %%
df.rename(columns={' Storage': 'Storage'}, inplace=True)

# %%
df['Storage']
# Out:
# 0                 128GB SSD
# 1       128GB Flash Storage
# 2                 256GB SSD
# 3                 512GB SSD
# 4                 256GB SSD
#                ...
# 1298              128GB SSD
# 1299              512GB SSD
# 1300     64GB Flash Storage
# 1301                1TB HDD
# 1302              500GB HDD
# Name: Storage, Length: 1303, dtype: object

# %%
a = pd.crosstab(df['Manufacturer'] , df['RAM'])
b = pd.crosstab(df['Manufacturer'] , df['Storage'])

# %%
df.rename(columns=lambda x: x.strip(), inplace=True)

# %%
df.columns.tolist()
# Out:
# ['Manufacturer',
#  'Model Name',
#  'Category',
#  'Screen Size',
#  'Screen',
#  'CPU',
#  'RAM',
#  'Storage',
#  'GPU',
#  'Operating System',
#  'Operating System Version',
#  'Weight',
#  'Price (Euros)']

# %%
df.rename(columns={'Storage': ' Storage'}, inplace=True)

# %%
df.columns.tolist()
# Out:
# ['Manufacturer',
#  'Model Name',
#  'Category',
#  'Screen Size',
#  'Screen',
#  'CPU',
#  'RAM',
#  ' Storage',
#  'GPU',
#  'Operating System',
#  'Operating System Version',
#  'Weight',
#  'Price (Euros)']

# %%
df.rename(columns=lambda x: x.strip(), inplace=True)

# %%
df.columns.tolist()
# Out:
# ['Manufacturer',
#  'Model Name',
#  'Category',
#  'Screen Size',
#  'Screen',
#  'CPU',
#  'RAM',
#  'Storage',
#  'GPU',
#  'Operating System',
#  'Operating System Version',
#  'Weight',
#  'Price (Euros)']

# %%
df.groupby(['Manufacturer']).mean(numeric_only=True)
# Out:
# Empty DataFrame
# Columns: []
# Index: [Acer, Apple, Asus, Chuwi, Dell, Fujitsu, Google, HP, Huawei, LG, Lenovo, MSI, Mediacom, Microsoft, Razer, Samsung, Toshiba, Vero, Xiaomi]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              1303 non-null   object
#  1   Model Name                1303 non-null   object
#  2   Category                  1303 non-null   object
#  3   Screen Size               1303 non-null   object
#  4   Screen                    1303 non-null   object
#  5   CPU                       1303 non-null   object
#  6   RAM                       1303 non-null   object
#  7   Storage                   1303 non-null   object
#  8   GPU                       1303 non-null   object
#  9   Operating System          1303 non-null   object
#  10  Operating System Version  1133 non-null   object
#  11  Weight                    1303 non-null   object
#  12  Price (Euros)             1303 non-null   object
# dtypes: object(13)
# memory usage: 132.5+ KB

# %%
df.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# ...

# %%
df['Price (Euros)']
# Out:
# 0       1339,69
# 1        898,94
# 2        575,00
# 3       2537,45
# 4       1803,60
#          ...
# 1298     638,00
# 1299    1499,00
# 1300     229,00
# 1301     764,00
# 1302     369,00
# Name: Price (Euros), Length: 1303, dtype: object

# %%
df['Price (Euros)'] = df['Price (Euros)'].str.replace(',' , '')

# %%
df['Price (Euros)']
# Out:
# 0       133969
# 1        89894
# 2        57500
# 3       253745
# 4       180360
#          ...
# 1298     63800
# 1299    149900
# 1300     22900
# 1301     76400
# 1302     36900
# Name: Price (Euros), Length: 1303, dtype: object

# %%
df['Price (Euros)'] = df['Price (Euros)'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              1303 non-null   object
#  1   Model Name                1303 non-null   object
#  2   Category                  1303 non-null   object
#  3   Screen Size               1303 non-null   object
#  4   Screen                    1303 non-null   object
#  5   CPU                       1303 non-null   object
#  6   RAM                       1303 non-null   object
#  7   Storage                   1303 non-null   object
#  8   GPU                       1303 non-null   object
#  9   Operating System          1303 non-null   object
#  10  Operating System Version  1133 non-null   object
#  11  Weight                    1303 non-null   object
#  12  Price (Euros)             1303 non-null   int32
# dtypes: int32(1), object(12)
# ...

# %%
df.groupby(['Manufacturer']).mean(numeric_only = True)
# Out:
#               Price (Euros)
# Manufacturer
# Acer           62677.582524
# Apple         156419.857143
# Asus          110416.936709
# Chuwi          31429.666667
# Dell          118606.898990
# Fujitsu        72900.000000
# Google        167766.666667
# HP            106777.485401
# Huawei        142400.000000
# LG            209900.000000
# Lenovo        108638.444444
# MSI           172890.814815
# Mediacom       29500.000000
# Microsoft     161230.833333
# Razer         334614.285714
# Samsung       141344.444444
# Toshiba       126781.250000
# Vero           21742.500000
# Xiaomi        113346.250000

# %%
pd.crosstab(df['Manufacturer'], df['Price (Euros)'])
# Out:
# Price (Euros)  17400   19190   19600   19900   20290   20900   21080   22400   \
# Manufacturer
# Acer                1       0       0       1       0       1       0       0
# Apple               0       0       0       0       0       0       0       0
# Asus                0       1       0       1       0       0       0       1
# Chuwi               0       0       0       0       0       0       0       0
# Dell                0       0       0       0       0       0       0       0
# Fujitsu             0       0       0       0       0       0       0       0
# Google              0       0       0       0       0       0       0       0
# HP                  0       0       0       0       0       3       0       0
# Huawei              0       0       0       0       0       0       0       0
# LG                  0       0       0       0       0       0       0       0
# Lenovo              0       0       0       0       0       0       0       0
# ...

# %%
df[(df['Manufacturer'] == 'Acer') & (df['Price (Euros)'] > 50000)]
# Out:
#      Manufacturer                                     Model Name  \
# 9            Acer                                        Swift 3
# 43           Acer                                Aspire A515-51G
# 51           Acer                                Aspire A515-51G
# 78           Acer                           Aspire A515-51G-32MX
# 91           Acer                                       Aspire 5
# 95           Acer                                         Spin 5
# 132          Acer                                        Swift 3
# 133          Acer                           Aspire A515-51G-37JS
# 140          Acer                                       Aspire 5
# 161          Acer                                Aspire A517-51G
# 168          Acer                                Aspire A517-51G
# 188          Acer                                        Swift 7
# 202          Acer                                 Aspire E5-576G
# ...

# %%
df.groupby(['Manufacturer']).median(numeric_only = True)
# Out:
#               Price (Euros)
# Manufacturer
# Acer                55900.0
# Apple              133969.0
# Asus               101250.0
# Chuwi               24890.0
# Dell                98500.0
# Fujitsu             73900.0
# Google             155900.0
# HP                  96650.0
# Huawei             142400.0
# LG                 209900.0
# Lenovo              89900.0
# MSI                159900.0
# Mediacom            26500.0
# Microsoft          156950.0
# Razer              289900.0
# Samsung            164900.0
# Toshiba            121150.0
# Vero                20685.0
# Xiaomi             109945.0

# %%
df['Price (Euros)'].plot()
# Out:
# <Axes: >

# %%
df['Price (Euros)'].max()
# Out:
# 609900

# %%
# df['Weight'] = df['Weight'].str.replace('[a-zA-Z]','', regex=True).astype('float')

# %%
df['Weight']
# Out:
# 0       1.37kg
# 1       1.34kg
# 2       1.86kg
# 3       1.83kg
# 4       1.37kg
#          ...
# 1298     1.8kg
# 1299     1.3kg
# 1300     1.5kg
# 1301    2.19kg
# 1302     2.2kg
# Name: Weight, Length: 1303, dtype: object

# %%
df['Weight'].str.lower()
# Out:
# 0       1.37kg
# 1       1.34kg
# 2       1.86kg
# 3       1.83kg
# 4       1.37kg
#          ...
# 1298     1.8kg
# 1299     1.3kg
# 1300     1.5kg
# 1301    2.19kg
# 1302     2.2kg
# Name: Weight, Length: 1303, dtype: object

# %% [markdown]
# ## Manupulating

# %%
data = {
    'name' : ['prashant' , 'sai', 'chetan', 'pavan' , 'rohit'],
    'salary' : [343253,45432,'',32323,''],
    'age': [ 21,21,'',12,24]
    
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#        name  salary age
# 0  prashant  343253  21
# 1       sai   45432  21
# 2    chetan
# 3     pavan   32323  12
# 4     rohit          24

# %%
data1 = {
    'name' : ['prashant' , 'sai', 'chetan', 'pavan' , 'rohit'],
    'salary' : [343253,45432,0 ,32323,0],
    'age': [ 21,21,0 ,12,24]
    
}

# %%
dff = pd.DataFrame(data1)

# %%
dff
# Out:
#        name  salary  age
# 0  prashant  343253   21
# 1       sai   45432   21
# 2    chetan       0    0
# 3     pavan   32323   12
# 4     rohit       0   24

# %%
dff['salary'].fillna(dff['salary'].mean(), inplace=True )
# Out:
# C:\Users\pdcha\AppData\Local\Temp\ipykernel_10400\61525223.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dff['salary'].fillna(dff['salary'].mean(), inplace=True)

# %%
df1 = pd.read_csv('employees.csv')

# %%
df1.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df1
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df1.sample(10)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 97       Laura     NaN   7/19/2014         9:23 PM  140371   10.620
# 666     Harold     NaN    2/4/2004        11:02 AM   79459    7.776
# 86       Annie     NaN   9/29/2007        12:11 AM  103495   17.290
# 274     Howard    Male   10/5/1982         7:22 AM   97490    5.460
# 445      Chris    Male  12/12/2006         1:57 AM   71642    1.496
# 228      Bobby    Male   9/23/1994         1:29 AM   51685   17.445
# 923      Irene     NaN   2/28/1991        10:23 PM  135369    4.380
# 597     Teresa  Female   6/24/1987         7:37 PM   69740    8.294
# 487     Cheryl  Female   12/3/2014         9:27 AM   71751   15.918
# 335     Robert    Male  11/18/2014         5:00 AM   85799   19.930
#
#     Senior Management                  Team
# 97               True             Marketing
# 666              True  Business Development
# 86               True  Business Development
# ...

# %%
df1['Team'].fillna(df1['Team']=='Finance')
# Out:
# 0                 Marketing
# 1                     False
# 2                   Finance
# 3                   Finance
# 4           Client Services
#                ...
# 995            Distribution
# 996                 Finance
# 997                 Product
# 998    Business Development
# 999                   Sales
# Name: Team, Length: 1000, dtype: object

# %%
df1.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df1['Team'].fillna(df1['Team'] == 'Finance' , inplace = True)

# %%
df1.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True            False
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
emp = pd.read_csv('employees.csv')

# %%
emp.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
droped_missing = emp.dropna()
droped_missing
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 2        Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male  1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male  4/18/1987         1:35 AM  115163   10.125
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 2               False               Finance
# ...

# %%
droped_missing.to_csv('emp_dropped_missing.csv')

# %%
dropped = pd.read_csv("emp_dropped_missing.csv")

# %%
dropped
# Out:
#      Unnamed: 0 First Name  Gender Start Date Last Login Time  Salary  \
# 0             0    Douglas    Male   8/6/1993        12:42 PM   97308
# 1             2      Maria  Female  4/23/1993        11:17 AM  130590
# 2             3      Jerry    Male   3/4/2005         1:00 PM  138705
# 3             4      Larry    Male  1/24/1998         4:47 PM  101004
# 4             5     Dennis    Male  4/18/1987         1:35 AM  115163
# ..          ...        ...     ...        ...             ...     ...
# 759         994     George    Male  6/21/2013         5:47 PM   98874
# 760         996    Phillip    Male  1/31/1984         6:30 AM   42392
# 761         997    Russell    Male  5/20/2013        12:39 PM   96914
# 762         998      Larry    Male  4/20/2013         4:45 PM   60500
# 763         999     Albert    Male  5/15/2012         6:24 PM  129949
#
#      Bonus %  Senior Management                  Team
# 0      6.945               True             Marketing
# ...

# %% [markdown]
# ### create Columns

# %%
dropped.drop(columns = ['Unnamed: 0'] , inplace = True)

# %%
dropped.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 2      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 3      Larry    Male  1/24/1998         4:47 PM  101004    1.389
# 4     Dennis    Male  4/18/1987         1:35 AM  115163   10.125
#
#    Senior Management             Team
# 0               True        Marketing
# 1              False          Finance
# 2               True          Finance
# 3               True  Client Services
# 4              False            Legal

# %%
#column from series
top_rows = dropped.head(10)

# %%
top_rows
# Out:
#   First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1      Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 2      Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 3      Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 4     Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 5       Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 6     Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 7    Frances  Female    8/8/2002         6:51 AM  139852    7.524
# 8      Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 9    Brandon    Male   12/1/1980         1:08 AM  112807   17.492
#
#    Senior Management                  Team
# 0               True             Marketing
# 1              False               Finance
# 2               True               Finance
# 3               True       Client Services
# ...

# %%
experience  = pd.Series([3,5,7,3,2,7])

# %%
top_rows['exp'] = experience
# Out:
# C:\Users\pdcha\AppData\Local\Temp\ipykernel_10400\1241131642.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_rows['exp'] = experience

# %%
top_rows
# Out:
#   First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1      Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 2      Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 3      Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 4     Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 5       Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 6     Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 7    Frances  Female    8/8/2002         6:51 AM  139852    7.524
# 8      Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 9    Brandon    Male   12/1/1980         1:08 AM  112807   17.492
#
#    Senior Management                  Team  exp
# 0               True             Marketing  3.0
# 1              False               Finance  5.0
# 2               True               Finance  7.0
# ...

# %%
top_rows['exp'].fillna(4 , inplace=True)
# Out:
# C:\Users\pdcha\AppData\Local\Temp\ipykernel_10400\815556295.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   top_rows['exp'].fillna(4 , inplace=True)
# C:\Users\pdcha\AppData\Local\Temp\ipykernel_10400\815556295.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_rows['exp'].fillna(4 , inplace=True)

# %%
top_rows
# Out:
#   First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1      Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 2      Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 3      Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 4     Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 5       Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 6     Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 7    Frances  Female    8/8/2002         6:51 AM  139852    7.524
# 8      Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 9    Brandon    Male   12/1/1980         1:08 AM  112807   17.492
#
#    Senior Management                  Team  exp
# 0               True             Marketing  3.0
# 1              False               Finance  5.0
# 2               True               Finance  7.0
# ...

# %%
increment = [20.15,14.5,16.7,10,24.5,32.2,10.6,5.5,9.0,20.5]

# %%
top_rows['increment (percent)'] = increment
# Out:
# C:\Users\pdcha\AppData\Local\Temp\ipykernel_10400\96241703.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_rows['increment (percent)'] = increment

# %%
top_rows
# Out:
#   First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1      Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 2      Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 3      Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 4     Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 5       Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 6     Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 7    Frances  Female    8/8/2002         6:51 AM  139852    7.524
# 8      Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 9    Brandon    Male   12/1/1980         1:08 AM  112807   17.492
#
#    Senior Management                  Team  exp  increment (percent)
# 0               True             Marketing  3.0                20.15
# 1              False               Finance  5.0                14.50
# ...

# %% [markdown]
# # shuffeling the data

# %%
emp_shuffle = top_rows.sample(frac=1)

# %%
emp_shuffle
# Out:
#   First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1      Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 9    Brandon    Male   12/1/1980         1:08 AM  112807   17.492
# 7    Frances  Female    8/8/2002         6:51 AM  139852    7.524
# 8      Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 4     Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6     Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 5       Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 2      Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 3      Larry    Male   1/24/1998         4:47 PM  101004    1.389
#
#    Senior Management                  Team  exp  increment (percent)
# 0               True             Marketing  3.0                20.15
# 1              False               Finance  5.0                14.50
# ...

# %%
emp_shuffle.reset_index()
# Out:
#    index First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      0    Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1      1      Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 2      9    Brandon    Male   12/1/1980         1:08 AM  112807   17.492
# 3      7    Frances  Female    8/8/2002         6:51 AM  139852    7.524
# 4      8      Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 5      4     Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6      6     Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 7      5       Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 8      2      Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 9      3      Larry    Male   1/24/1998         4:47 PM  101004    1.389
#
#    Senior Management                  Team  exp  increment (percent)
# 0               True             Marketing  3.0                20.15
# ...

# %%
emp_shuffle.reset_index(drop = True , inplace = True)

# %%
emp_shuffle
# Out:
#   First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1      Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 2    Brandon    Male   12/1/1980         1:08 AM  112807   17.492
# 3    Frances  Female    8/8/2002         6:51 AM  139852    7.524
# 4      Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 5     Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6     Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 7       Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 8      Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 9      Larry    Male   1/24/1998         4:47 PM  101004    1.389
#
#    Senior Management                  Team  exp  increment (percent)
# 0               True             Marketing  3.0                20.15
# 1              False               Finance  5.0                14.50
# ...

# %%
top_rows
# Out:
#   First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1      Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 2      Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 3      Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 4     Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 5       Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 6     Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 7    Frances  Female    8/8/2002         6:51 AM  139852    7.524
# 8      Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 9    Brandon    Male   12/1/1980         1:08 AM  112807   17.492
#
#    Senior Management                  Team  exp  increment (percent)
# 0               True             Marketing  3.0                20.15
# 1              False               Finance  5.0                14.50
# ...
