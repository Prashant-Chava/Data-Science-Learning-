# %%
# NumPy Array Basics

# %%
# importing 
import numpy as np

# %%
# creating the 1d numpy array
a1 = np.array([1,2,3,4,5,6])

# %%
a1
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
# 2d matrix 2 rows and 3 columns
matrix = np.array([[1,2,3],
                   [4,5,6]])
matrix
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
# 2. Understanding Array Properties

# %%
# number of dimentions
matrix.ndim
# Out:
# 2

# %%
# array shape
matrix.shape
# Out:
# (2, 3)

# %%
# total  number of elements
matrix.size
# Out:
# 6

# %%
# datatype
matrix.dtype
# Out:
# dtype('int32')

# %%
# 3. Converting Data Type
# Sometimes matrix problems require float → int or int → float.
float = matrix.astype(float)

# %%
# Why is This Section Important?
# These decide
# 🔸 whether you can multiply matrices
# 🔸 whether reshape will work
# 🔸 whether slicing will work
# 🔸 whether broadcasting will work
