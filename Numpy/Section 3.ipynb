# %% [markdown]
# ## SECTION 3 — Indexing & Slicing

# %% [raw]
# 🔹 What it is:
#
# Selecting specific rows, columns, or portions of a matrix.
#
# 🔹 Why it's used:
#
# Extract sub-matrices
# Access elements
# Modify parts of a matrix
# Solve mathematical/ML problems
# Implement algorithms (like convolution, transformations)

# %%
import numpy as np

# %%
a1 = np.array([[10,20,30],
               [40,50,60],
               [70,80,90]])

# %%
# 1. Basic Element Access
# For a matrix A[row, column]
a1[0,0]  # first row first col
# Out:
# 10

# %%
a1[2,1]   # second row first col
# Out:
# 80

# %%
a1[1,2]   # 1st row 2nd col
# Out:
# 60

# %%
# 2. Selecting an Entire Row
a1[1]
# Out:
# array([40, 50, 60])

# %%
a1[1,:]
# Out:
# array([40, 50, 60])

# %%
a1[3] # index error will get if we try to fetch the row which is greter than the size of matrix
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 a1[3]
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %%
a1[2]
# Out:
# array([70, 80, 90])

# %%
# 3. Selecting an Entire Column
a1[:,1]
# Out:
# array([20, 50, 80])

# %%
a1[:,2]
# Out:
# array([30, 60, 90])

# %%
a1[:, 0]
# Out:
# array([10, 40, 70])

# %%
# 4. Slicing (start : end)
# a1[row_start : row_end, column_start : column_end]

# %%
a1
# Out:
# array([[10, 20, 30],
#        [40, 50, 60],
#        [70, 80, 90]])

# %%
a1[2:, 2:]
# Out:
# array([[90]])

# %%
# 50
a1[1:2, 1:2]
# Out:
# array([[50]])

# %%
#30
a1[:1, 2:3]
# Out:
# array([[30]])

# %%
# 5. Negative Indexing
a1[-1]  # last row
# Out:
# array([70, 80, 90])

# %%
a1[:, -1]  # last col
# Out:
# array([30, 60, 90])

# %%
# 6. Submatrix Extraction (Very Important)
 # i want this middle block
# 50,60
# 80,90

# %%
a1
# Out:
# array([[10, 20, 30],
#        [40, 50, 60],
#        [70, 80, 90]])

# %%
a1[1:3 , 1:3]
# Out:
# array([[50, 60],
#        [80, 90]])

# %%
# [40, 50,]
# [70, 80,]
a1[1:3 , :2]
# Out:
# array([[40, 50],
#        [70, 80]])

# %%
# SECTION 3 – Practice Questions
a2 = np.array([
    [3, 8, 9, 1],
    [4, 6, 7, 2],
    [5, 0, 3, 8],
    [9, 1, 4, 6]
])
a2
# Out:
# array([[3, 8, 9, 1],
#        [4, 6, 7, 2],
#        [5, 0, 3, 8],
#        [9, 1, 4, 6]])

# %%
# a2[2, 3]
# Second row
# Third column
# Last row
# Last column
# Submatrix:
  #[[6, 7],
 #[0, 3]]
# First 2 rows & first 3 columns

# %%
a2[2,3]
# Out:
# 8

# %%
# 2.
a2[2:3, :]
# Out:
# array([[5, 0, 3, 8]])

# %%
# 3.
a2[:, 3:4]
# Out:
# array([[1],
#        [2],
#        [8],
#        [6]])

# %%
# 4.
a2[3:]
# Out:
# array([[9, 1, 4, 6]])

# %%
# 5.
a2[:, 3:]
# Out:
# array([[1],
#        [2],
#        [8],
#        [6]])

# %%
# 6.submatrix 6,7,0,3
a2
# Out:
# array([[3, 8, 9, 1],
#        [4, 6, 7, 2],
#        [5, 0, 3, 8],
#        [9, 1, 4, 6]])

# %%
a2[1:3, 1:3]
# Out:
# array([[6, 7],
#        [0, 3]])

# %%
# 7.
a2[:2, :3]
# Out:
# array([[3, 8, 9],
#        [4, 6, 7]])
